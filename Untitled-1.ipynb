# %%
import pandas as pd
import numpy as np

# %%
f = "C:/Users/IlhamAkbarRamadhan/mediaagentur-in.berlin/Ilham - Documents/VSCODE/py/imports-85.data"
headers = ["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style",
"drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
"num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower", "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df = pd.read_csv(f, header=None)
df.columns = headers

# %%
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
path="C:/Users/IlhamAkbarRamadhan/mediaagentur-in.berlin/Ilham - Documents/VSCODE/py/automobile.csv"
df.to_csv(path)

# %%
df = pd.read_csv(
    "C:/Users/IlhamAkbarRamadhan/mediaagentur-in.berlin/Ilham - Documents/VSCODE/py/automobile.csv")

# %%
df1=df.replace('?',np.NaN)

# %%
df = df1.dropna(subset=["price"], axis=0)
df.head(20)
# Out:
#     Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0            0          3               NaN  alfa-romero       gas        std
# 1            1          3               NaN  alfa-romero       gas        std
# 2            2          1               NaN  alfa-romero       gas        std
# 3            3          2               164         audi       gas        std
# 4            4          2               164         audi       gas        std
# 5            5          2               NaN         audi       gas        std
# 6            6          1               158         audi       gas        std
# 7            7          1               NaN         audi       gas        std
# 8            8          1               158         audi       gas      turbo
# 10          10          2               192          bmw       gas        std
# 11          11          0               192          bmw       gas        std
# ...

# %%
df.describe(include = "all")
# Out:
#         Unnamed: 0   symboling normalized-losses    make fuel-type aspiration  \
# count   201.000000  201.000000               164     201       201        201
# unique         NaN         NaN                51      22         2          2
# top            NaN         NaN               161  toyota       gas        std
# freq           NaN         NaN                11      32       181        165
# mean    102.900498    0.840796               NaN     NaN       NaN        NaN
# std      59.234956    1.254802               NaN     NaN       NaN        NaN
# min       0.000000   -2.000000               NaN     NaN       NaN        NaN
# 25%      53.000000    0.000000               NaN     NaN       NaN        NaN
# 50%     103.000000    1.000000               NaN     NaN       NaN        NaN
# 75%     154.000000    2.000000               NaN     NaN       NaN        NaN
# max     204.000000    3.000000               NaN     NaN       NaN        NaN
#
# ...

# %%
df.to_csv("automobile.csv", index=False)
